# %%
print()

# %%
# pip install sentence-transformers

# %%
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter
import spacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
data = open('tn_data.txt',encoding='utf-8').read()
data
# Out:
# 'Hello Everyone!! 👋😊\n\nI\'m Sam, and I\'ve been learnng Natural Language Processing (NLP) for almost 2 years. Honestly, it\'s amazng! 🚀❤️\n\nYesterday, I visitted OpenAI\'s website at https://openai.com and also checked https://python.org for Python documentation. I\'ve also used LangChain, PyTorch, TensorFlow, HuggingFace, and SpaCy for building AI applications.\n\nYou can contact me at Sam.Example123@gmail.com or office_email@test-company.co.in.\nMy phone numbers are +91-9876543210 and (080)-2345-6789.\n\nToday\'s date is 25/07/2026, and my employee ID is EMP#A-1024.\nThe project budget is $2,500.75 (approximately ₹2,15,000).\n\nI don\'t think AI is replacing humans—it isn\'t! Instead, it\'s helping people become more productive. You\'re going to love learning it because it\'s practical and exciting.\n\nMy favourite sentence is:\n"Machine Learning isn\'t magic; it\'s mathematics, statistics, and lots of data."\n\nSome common spelling mistakes:\nmachne learnng\nartificail inteligen
# ...

# %%
splitter = RecursiveCharacterTextSplitter(chunk_size=100, chunk_overlap=20)

# %% [markdown]
# split text and split documents

# %%
chunks = splitter.split_text(data)
print(chunks, type(chunks), type(chunks[0])) # split_text returns list of strings(chunks)
# Out:
# ['Hello Everyone!! 👋😊', "I'm Sam, and I've been learnng Natural Language Processing (NLP) for almost 2 years. Honestly, it's", "Honestly, it's amazng! 🚀❤️", "Yesterday, I visitted OpenAI's website at https://openai.com and also checked https://python.org", "https://python.org for Python documentation. I've also used LangChain, PyTorch, TensorFlow,", 'TensorFlow, HuggingFace, and SpaCy for building AI applications.', 'You can contact me at Sam.Example123@gmail.com or office_email@test-company.co.in.', 'My phone numbers are +91-9876543210 and (080)-2345-6789.', "Today's date is 25/07/2026, and my employee ID is EMP#A-1024.", 'The project budget is $2,500.75 (approximately ₹2,15,000).', "I don't think AI is replacing humans—it isn't! Instead, it's helping people become more productive.", "more productive. You're going to love learning it because it's practical and exciting.", 'My favourite sentence is:', '"Machine Learning isn\'t magic; it\'s mathematics, statistics, and lots of data."'
# ...

# %%
embeddings = SentenceTransformer(
    model_name_or_path = 'sentence-transformers/all-miniLM-L6-V2'
)
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 3730.49it/s]

# %% [markdown]
# - while explaining in interview, give SentenceTransformer example ('sentence-transformers/all-miniLM-L6-V2')
# - embedding model
# - importance of embedding model
# - sentence_transformers

# %%
embeddings.encode(chunks)
# Out:
# array([[-0.02934772,  0.00856362,  0.09771862, ...,  0.03832595,
#          0.01111126,  0.01367354],
#        [-0.01520071, -0.07243886,  0.05744056, ...,  0.08066782,
#         -0.01843977,  0.06069823],
#        [-0.07630333,  0.06387175,  0.06414419, ..., -0.04640891,
#         -0.01466371,  0.00468549],
#        ...,
#        [-0.0883971 , -0.04041932,  0.03950174, ...,  0.08876637,
#          0.14251623,  0.03043227],
#        [-0.00770202, -0.02931372,  0.00958457, ...,  0.01755717,
#          0.07053382,  0.04071227],
#        [-0.01806227, -0.06446507,  0.01131533, ..., -0.03147467,
#          0.07344343,  0.01229705]], shape=(30, 384), dtype=float32)

# %%
# be default, the model uses 384 dimensions.
# text embedding 001
