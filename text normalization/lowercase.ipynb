# %%
print()

# %%
import pandas as pd

# %%
with open('data.txt','r+') as fh:
        data = fh.read().lower()  #read method returns string so we can use lower method on it
        fh.seek(0)
        fh.write(data)
