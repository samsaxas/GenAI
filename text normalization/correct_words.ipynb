# %%
print()

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
text = 'correcting the wods for text normalization'
text1 = 'the rouger is not working'

corrected_words = TextBlob(text1).correct()
print(type(corrected_words), corrected_words)
# Out:
# <class 'textblob.blob.TextBlob'> the roger is not working
