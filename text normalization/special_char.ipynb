# %%
print()

# %%
# to remove punctuations from the data.txt
with open('data.txt', 'r+') as file:
    data = file.read()
    for char in data:
        if char.isalnum() or ord(char) == 32:
            data = data.replace(char, '')
            print(data)
            print()
# Out:
# ython is a high level object oriented dynamically tyed interreted structural as well as rogramming language
#  language
# Python is a highlevel objectoriented dynamically tyed interreted rogramming language
#
#
# Oen file and return a stream. Raise OSError uon failure.
#
# file is either a text or byte string giving the name (and the ath
# if the file isn't in the current working directory) of the file to
# be oened or an integer file descritor of the file to be
# wraed. (If a file descritor is given, it is closed when the
# returned I/O object is closed, unless closefd is set to False.)
#
# mode is an otional string that secifies the mode in which the file
# is oened. It defaults to 'r' which means oen for reading in text
# mode. Other common values are 'w' for writing (truncating the file if
# it already exists), 'x' for creating and writing to a new file, and
# 'a' for aending (which on some Unix systems, means that all writes
# aend to the end of the file regardless of the current seek osition).
# In text mode, if encoding is not secified the encoding used is latform
# deendent: locale.getencoding() is called to get the current locale encoding.
# (For reading and writing raw bytes use binary mode and leave encoding
# unsecified.) The available modes are:
#
# thon is a high level object oriented dnamicall ted interreted structural as well as rogramming language
#  language
# Pthon is a highlevel objectoriented dnamicall ted interreted rogramming language
#
#
# Oen file and return a stream. Raise OSError uon failure.
#
# file is either a text or bte string giving the name (and the ath
# if the file isn't in the current working director) of the file to
# be oened or an integer file descritor of the file to be
# wraed. (If a file descritor is given, it is closed when the
# returned I/O object is closed, unless closefd is set to False.)
#
# mode is an otional string that secifies the mode in which the file
# is oened. It defaults to 'r' which means oen for reading in text
# mode. Other common values are 'w' for writing (truncating the file if
# it alread exists), 'x' for creating and writing to a new file, and
# 'a' for aending (which on some Unix sstems, means that all writes
# aend to the end of the file regardless of the current seek osition).
# In text mode, if encoding is not secified the encoding used is latform
# deendent: locale.getencoding() is called to get the current locale encoding.
# (For reading and writing raw btes use binar mode and leave encoding
# unsecified.) The available modes are:
#
# hon is a high level objec oriened dnamicall ed inerreed srucural as well as rogramming language
#  language
# Phon is a highlevel objecoriened dnamicall ed inerreed rogramming language
#
#
# Oen file and reurn a sream. Raise OSError uon failure.
#
# file is eiher a ex or be sring giving he name (and he ah
# if he file isn' in he curren working direcor) of he file o
# be oened or an ineger file descrior of he file o be
# wraed. (If a file descrior is given, i is closed when he
# reurned I/O objec is closed, unless closefd is se o False.)
#
# mode is an oional sring ha secifies he mode in which he file
# is oened. I defauls o 'r' which means oen for reading in ex
# mode. Oher common values are 'w' for wriing (runcaing he file if
# i alread exiss), 'x' for creaing and wriing o a new file, and
# 'a' for aending (which on some Unix ssems, means ha all wries
# aend o he end of he file regardless of he curren seek osiion).
# In ex mode, if encoding is no secified he encoding used is laform
# deenden: locale.geencoding() is called o ge he curren locale encoding.
# (For reading and wriing raw bes use binar mode and leave encoding
# unsecified.) The available modes are:
#
# on is a ig level objec oriened dnamicall ed inerreed srucural as well as rogramming language
#  language
# Pon is a iglevel objecoriened dnamicall ed inerreed rogramming language
#
#
# Oen file and reurn a sream. Raise OSError uon failure.
#
# file is eier a ex or be sring giving e name (and e a
# if e file isn' in e curren working direcor) of e file o
# be oened or an ineger file descrior of e file o be
# wraed. (If a file descrior is given, i is closed wen e
# reurned I/O objec is closed, unless closefd is se o False.)
#
# mode is an oional sring a secifies e mode in wic e file
# is oened. I defauls o 'r' wic means oen for reading in ex
# mode. Oer common values are 'w' for wriing (runcaing e file if
# i alread exiss), 'x' for creaing and wriing o a new file, and
# 'a' for aending (wic on some Unix ssems, means a all wries
# aend o e end of e file regardless of e curren seek osiion).
# In ex mode, if encoding is no secified e encoding used is laform
# deenden: locale.geencoding() is called o ge e curren locale encoding.
# (For reading and wriing raw bes use binar mode and leave encoding
# unsecified.) Te available modes are:
#
# n is a ig level bjec riened dnamicall ed inerreed srucural as well as rgramming language
#  language
# Pn is a iglevel bjecriened dnamicall ed inerreed rgramming language
#
#
# Oen file and reurn a sream. Raise OSErrr un failure.
#
# file is eier a ex r be sring giving e name (and e a
# if e file isn' in e curren wrking direcr) f e file
# be ened r an ineger file descrir f e file  be
# wraed. (If a file descrir is given, i is clsed wen e
# reurned I/O bjec is clsed, unless clsefd is se  False.)
#
# mde is an inal sring a secifies e mde in wic e file
# is ened. I defauls  'r' wic means en fr reading in ex
# mde. Oer cmmn values are 'w' fr wriing (runcaing e file if
# i alread exiss), 'x' fr creaing and wriing  a new file, and
# 'a' fr aending (wic n sme Unix ssems, means a all wries
# aend  e end f e file regardless f e curren seek siin).
# In ex mde, if encding is n secified e encding used is lafrm
# deenden: lcale.geencding() is called  ge e curren lcale encding.
# (Fr reading and wriing raw bes use binar mde and leave encding
# unsecified.) Te available mdes are:
#
#  is a ig level bjec rieed damicall ed ierreed srucural as well as rgrammig laguage
#  laguage
# P is a iglevel bjecrieed damicall ed ierreed rgrammig laguage
#
#
# Oe file ad reur a sream. Raise OSErrr u failure.
#
# file is eier a ex r be srig givig e ame (ad e a
# if e file is' i e curre wrkig direcr) f e file
# be eed r a ieger file descrir f e file  be
# wraed. (If a file descrir is give, i is clsed we e
# reured I/O bjec is clsed, uless clsefd is se  False.)
#
# mde is a ial srig a secifies e mde i wic e file
# is eed. I defauls  'r' wic meas e fr readig i ex
# mde. Oer cmm values are 'w' fr wriig (rucaig e file if
# i alread exiss), 'x' fr creaig ad wriig  a ew file, ad
# 'a' fr aedig (wic  sme Uix ssems, meas a all wries
# aed  e ed f e file regardless f e curre seek sii).
# I ex mde, if ecdig is  secified e ecdig used is lafrm
# deede: lcale.geecdig() is called  ge e curre lcale ecdig.
# (Fr readig ad wriig raw bes use biar mde ad leave ecdig
# usecified.) Te available mdes are:
#
# isaiglevelbjecrieeddamicalledierreedsrucuralaswellasrgrammiglaguage
# laguage
# Pisaiglevelbjecrieeddamicalledierreedrgrammiglaguage
#
#
# Oefileadreurasream.RaiseOSErrrufailure.
#
# fileiseieraexrbesriggivigeame(adea
# ifefileis'iecurrewrkigdirecr)fefile
# beeedraiegerfiledescrirfefilebe
# wraed.(Ifafiledescririsgive,iisclsedwee
# reuredI/Objecisclsed,ulessclsefdisseFalse.)
#
# mdeisaialsrigasecifiesemdeiwicefile
# iseed.Idefauls'r'wicmeasefrreadigiex
# mde.Oercmmvaluesare'w'frwriig(rucaigefileif
# ialreadexiss),'x'frcreaigadwriigaewfile,ad
# 'a'fraedig(wicsmeUixssems,measaallwries
# aedeedfefileregardlessfecurreseeksii).
# Iexmde,ifecdigissecifiedeecdigusedislafrm
# deede:lcale.geecdig()iscalledgeecurrelcaleecdig.
# (Frreadigadwriigrawbesusebiarmdeadleaveecdig
# usecified.)Teavailablemdesare:
#
# saglevelbjecreeddamcallederreedsrucuralaswellasrgrammglaguage
# laguage
# Psaglevelbjecreeddamcallederreedrgrammglaguage
#
#
# Oefleadreurasream.RaseOSErrrufalure.
#
# fleseeraexrbesrggvgeame(adea
# fefles'ecurrewrkgdrecr)fefle
# beeedraegerfledescrrfeflebe
# wraed.(Ifafledescrrsgve,sclsedwee
# reuredI/Objecsclsed,ulessclsefdsseFalse.)
#
# mdesaalsrgasecfesemdewcefle
# seed.Idefauls'r'wcmeasefrreadgex
# mde.Oercmmvaluesare'w'frwrg(rucageflef
# alreadexss),'x'frcreagadwrgaewfle,ad
# 'a'fraedg(wcsmeUxssems,measaallwres
# aedeedfefleregardlessfecurreseeks).
# Iexmde,fecdgssecfedeecdgusedslafrm
# deede:lcale.geecdg()scalledgeecurrelcaleecdg.
# (Frreadgadwrgrawbesusebarmdeadleaveecdg
# usecfed.)Teavalablemdesare:
#
# aglevelbjecreeddamcallederreedrucuralawellargrammglaguage
# laguage
# Paglevelbjecreeddamcallederreedrgrammglaguage
#
#
# Oefleadreuraream.RaeOSErrrufalure.
#
# fleeeraexrberggvgeame(adea
# fefle'ecurrewrkgdrecr)fefle
# beeedraegerfledecrrfeflebe
# wraed.(Ifafledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFale.)
#
# mdeaalrgaecfeemdewcefle
# eed.Idefaul'r'wcmeaefrreadgex
# mde.Oercmmvalueare'w'frwrg(rucageflef
# alreadex),'x'frcreagadwrgaewfle,ad
# 'a'fraedg(wcmeUxem,meaaallwre
# aedeedfefleregardlefecurreeek).
# Iexmde,fecdgecfedeecdguedlafrm
# deede:lcale.geecdg()calledgeecurrelcaleecdg.
# (Frreadgadwrgrawbeuebarmdeadleaveecdg
# uecfed.)Teavalablemdeare:
#
# aglevelbjecreeddamcallederreedrucuralawellargrammglaguage
# laguage
# Paglevelbjecreeddamcallederreedrgrammglaguage
#
#
# Oefleadreuraream.RaeOSErrrufalure.
#
# fleeeraexrberggvgeame(adea
# fefle'ecurrewrkgdrecr)fefle
# beeedraegerfledecrrfeflebe
# wraed.(Ifafledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFale.)
#
# mdeaalrgaecfeemdewcefle
# eed.Idefaul'r'wcmeaefrreadgex
# mde.Oercmmvalueare'w'frwrg(rucageflef
# alreadex),'x'frcreagadwrgaewfle,ad
# 'a'fraedg(wcmeUxem,meaaallwre
# aedeedfefleregardlefecurreeek).
# Iexmde,fecdgecfedeecdguedlafrm
# deede:lcale.geecdg()calledgeecurrelcaleecdg.
# (Frreadgadwrgrawbeuebarmdeadleaveecdg
# uecfed.)Teavalablemdeare:
#
# glevelbjecreeddmcllederreedrucurlwellrgrmmglguge
# lguge
# Pglevelbjecreeddmcllederreedrgrmmglguge
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberggvgeme(de
# fefle'ecurrewrkgdrecr)fefle
# beeedregerfledecrrfeflebe
# wred.(Iffledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrgecfeemdewcefle
# eed.Ideful'r'wcmeefrredgex
# mde.Oercmmvluere'w'frwrg(rucgeflef
# lredex),'x'frcregdwrgewfle,d
# ''fredg(wcmeUxem,mellwre
# edeedfefleregrdlefecurreeek).
# Iexmde,fecdgecfedeecdguedlfrm
# deede:lcle.geecdg()clledgeecurrelcleecdg.
# (Frredgdwrgrwbeuebrmdedleveecdg
# uecfed.)Tevlblemdere:
#
# glevelbjecreeddmcllederreedrucurlwellrgrmmglguge
# lguge
# Pglevelbjecreeddmcllederreedrgrmmglguge
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberggvgeme(de
# fefle'ecurrewrkgdrecr)fefle
# beeedregerfledecrrfeflebe
# wred.(Iffledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrgecfeemdewcefle
# eed.Ideful'r'wcmeefrredgex
# mde.Oercmmvluere'w'frwrg(rucgeflef
# lredex),'x'frcregdwrgewfle,d
# ''fredg(wcmeUxem,mellwre
# edeedfefleregrdlefecurreeek).
# Iexmde,fecdgecfedeecdguedlfrm
# deede:lcle.geecdg()clledgeecurrelcleecdg.
# (Frredgdwrgrwbeuebrmdedleveecdg
# uecfed.)Tevlblemdere:
#
# glevelbjecreeddmcllederreedrucurlwellrgrmmglguge
# lguge
# Pglevelbjecreeddmcllederreedrgrmmglguge
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberggvgeme(de
# fefle'ecurrewrkgdrecr)fefle
# beeedregerfledecrrfeflebe
# wred.(Iffledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrgecfeemdewcefle
# eed.Ideful'r'wcmeefrredgex
# mde.Oercmmvluere'w'frwrg(rucgeflef
# lredex),'x'frcregdwrgewfle,d
# ''fredg(wcmeUxem,mellwre
# edeedfefleregrdlefecurreeek).
# Iexmde,fecdgecfedeecdguedlfrm
# deede:lcle.geecdg()clledgeecurrelcleecdg.
# (Frredgdwrgrwbeuebrmdedleveecdg
# uecfed.)Tevlblemdere:
#
# glevelbjecreeddmcllederreedrucurlwellrgrmmglguge
# lguge
# Pglevelbjecreeddmcllederreedrgrmmglguge
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberggvgeme(de
# fefle'ecurrewrkgdrecr)fefle
# beeedregerfledecrrfeflebe
# wred.(Iffledecrrgve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrgecfeemdewcefle
# eed.Ideful'r'wcmeefrredgex
# mde.Oercmmvluere'w'frwrg(rucgeflef
# lredex),'x'frcregdwrgewfle,d
# ''fredg(wcmeUxem,mellwre
# edeedfefleregrdlefecurreeek).
# Iexmde,fecdgecfedeecdguedlfrm
# deede:lcle.geecdg()clledgeecurrelcleecdg.
# (Frredgdwrgrwbeuebrmdedleveecdg
# uecfed.)Tevlblemdere:
#
# levelbjecreeddmcllederreedrucurlwellrrmmlue
# lue
# Plevelbjecreeddmcllederreedrrmmlue
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberveme(de
# fefle'ecurrewrkdrecr)fefle
# beeedreerfledecrrfeflebe
# wred.(Iffledecrrve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrecfeemdewcefle
# eed.Ideful'r'wcmeefrredex
# mde.Oercmmvluere'w'frwr(ruceflef
# lredex),'x'frcredwrewfle,d
# ''fred(wcmeUxem,mellwre
# edeedfeflererdlefecurreeek).
# Iexmde,fecdecfedeecduedlfrm
# deede:lcle.eecd()clledeecurrelcleecd.
# (Frreddwrrwbeuebrmdedleveecd
# uecfed.)Tevlblemdere:
#
# levelbjecreeddmcllederreedrucurlwellrrmmlue
# lue
# Plevelbjecreeddmcllederreedrrmmlue
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberveme(de
# fefle'ecurrewrkdrecr)fefle
# beeedreerfledecrrfeflebe
# wred.(Iffledecrrve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrecfeemdewcefle
# eed.Ideful'r'wcmeefrredex
# mde.Oercmmvluere'w'frwr(ruceflef
# lredex),'x'frcredwrewfle,d
# ''fred(wcmeUxem,mellwre
# edeedfeflererdlefecurreeek).
# Iexmde,fecdecfedeecduedlfrm
# deede:lcle.eecd()clledeecurrelcleecd.
# (Frreddwrrwbeuebrmdedleveecd
# uecfed.)Tevlblemdere:
#
# levelbjecreeddmcllederreedrucurlwellrrmmlue
# lue
# Plevelbjecreeddmcllederreedrrmmlue
#
#
# Oefledreurrem.ReOSErrruflure.
#
# fleeerexrberveme(de
# fefle'ecurrewrkdrecr)fefle
# beeedreerfledecrrfeflebe
# wred.(Iffledecrrve,cledwee
# reuredI/Objeccled,uleclefdeFle.)
#
# mdelrecfeemdewcefle
# eed.Ideful'r'wcmeefrredex
# mde.Oercmmvluere'w'frwr(ruceflef
# lredex),'x'frcredwrewfle,d
# ''fred(wcmeUxem,mellwre
# edeedfeflererdlefecurreeek).
# Iexmde,fecdecfedeecduedlfrm
# deede:lcle.eecd()clledeecurrelcleecd.
# (Frreddwrrwbeuebrmdedleveecd
# uecfed.)Tevlblemdere:
#
# evebjecreeddmcederreedrucurwerrmmue
# ue
# Pevebjecreeddmcederreedrrmmue
#
#
# Oefedreurrem.ReOSErrrufure.
#
# feeerexrberveme(de
# fefe'ecurrewrkdrecr)fefe
# beeedreerfedecrrfefebe
# wred.(Iffedecrrve,cedwee
# reuredI/Objecced,uecefdeFe.)
#
# mderecfeemdewcefe
# eed.Idefu'r'wcmeefrredex
# mde.Oercmmvuere'w'frwr(rucefef
# redex),'x'frcredwrewfe,d
# ''fred(wcmeUxem,mewre
# edeedfefererdefecurreeek).
# Iexmde,fecdecfedeecduedfrm
# deede:ce.eecd()cedeecurreceecd.
# (Frreddwrrwbeuebrmdedeveecd
# uecfed.)Tevbemdere:
#
# vbjcrddmcdrrdrucurwrrmmu
# u
# Pvbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrvm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrrv,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmvur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddvcd
# ucfd.)Tvbmdr:
#
# bjcrddmcdrrdrucurwrrmmu
# u
# Pbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrr,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddcd
# ucfd.)Tbmdr:
#
# bjcrddmcdrrdrucurwrrmmu
# u
# Pbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrr,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddcd
# ucfd.)Tbmdr:
#
# bjcrddmcdrrdrucurwrrmmu
# u
# Pbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrr,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddcd
# ucfd.)Tbmdr:
#
# bjcrddmcdrrdrucurwrrmmu
# u
# Pbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrr,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddcd
# ucfd.)Tbmdr:
#
# bjcrddmcdrrdrucurwrrmmu
# u
# Pbjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrbrm(d
# ff'currwrkdrcr)ff
# bdrrfdcrrffb
# wrd.(Iffdcrr,cdw
# rurdI/Objccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwbubrmddcd
# ucfd.)Tbmdr:
#
# jcrddmcdrrdrucurwrrmmu
# u
# Pjcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'currwrkdrcr)ff
# drrfdcrrff
# wrd.(Iffdcrr,cdw
# rurdI/Ojccd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwurmddcd
# ucfd.)Tmdr:
#
# crddmcdrrdrucurwrrmmu
# u
# Pcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'currwrkdrcr)ff
# drrfdcrrff
# wrd.(Iffdcrr,cdw
# rurdI/Occd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwurmddcd
# ucfd.)Tmdr:
#
# crddmcdrrdrucurwrrmmu
# u
# Pcrddmcdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'currwrkdrcr)ff
# drrfdcrrff
# wrd.(Iffdcrr,cdw
# rurdI/Occd,ucfdF.)
#
# mdrcfmdwcf
# d.Idfu'r'wcmfrrdx
# md.Orcmmur'w'frwr(rucff
# rdx),'x'frcrdwrwf,d
# ''frd(wcmUxm,mwr
# ddffrrdfcurrk).
# Ixmd,fcdcfdcdudfrm
# dd:c.cd()cdcurrccd.
# (Frrddwrrwurmddcd
# ucfd.)Tmdr:
#
# rddmdrrdruurwrrmmu
# u
# Prddmdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'urrwrkdrr)ff
# drrfdrrff
# wrd.(Iffdrr,dw
# rurdI/Od,ufdF.)
#
# mdrfmdwf
# d.Idfu'r'wmfrrdx
# md.Ormmur'w'frwr(ruff
# rdx),'x'frrdwrwf,d
# ''frd(wmUxm,mwr
# ddffrrdfurrk).
# Ixmd,fdfddudfrm
# dd:.d()durrd.
# (Frrddwrrwurmddd
# ufd.)Tmdr:
#
# rddmdrrdruurwrrmmu
# u
# Prddmdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'urrwrkdrr)ff
# drrfdrrff
# wrd.(Iffdrr,dw
# rurdI/Od,ufdF.)
#
# mdrfmdwf
# d.Idfu'r'wmfrrdx
# md.Ormmur'w'frwr(ruff
# rdx),'x'frrdwrwf,d
# ''frd(wmUxm,mwr
# ddffrrdfurrk).
# Ixmd,fdfddudfrm
# dd:.d()durrd.
# (Frrddwrrwurmddd
# ufd.)Tmdr:
#
# rddmdrrdruurwrrmmu
# u
# Prddmdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'urrwrkdrr)ff
# drrfdrrff
# wrd.(Iffdrr,dw
# rurdI/Od,ufdF.)
#
# mdrfmdwf
# d.Idfu'r'wmfrrdx
# md.Ormmur'w'frwr(ruff
# rdx),'x'frrdwrwf,d
# ''frd(wmUxm,mwr
# ddffrrdfurrk).
# Ixmd,fdfddudfrm
# dd:.d()durrd.
# (Frrddwrrwurmddd
# ufd.)Tmdr:
#
# rddmdrrdruurwrrmmu
# u
# Prddmdrrdrrmmu
#
#
# Ofdrurrm.ROSErrrufur.
#
# frxrrm(d
# ff'urrwrkdrr)ff
# drrfdrrff
# wrd.(Iffdrr,dw
# rurdI/Od,ufdF.)
#
# mdrfmdwf
# d.Idfu'r'wmfrrdx
# md.Ormmur'w'frwr(ruff
# rdx),'x'frrdwrwf,d
# ''frd(wmUxm,mwr
# ddffrrdfurrk).
# Ixmd,fdfddudfrm
# dd:.d()durrd.
# (Frrddwrrwurmddd
# ufd.)Tmdr:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# ddmdduuwmmu
# u
# Pddmddmmu
#
#
# Ofdum.ROSEufu.
#
# fxm(d
# ff'uwkd)ff
# dfdff
# wd.(Iffd,dw
# udI/Od,ufdF.)
#
# mdfmdwf
# d.Idfu''wmfdx
# md.Ommu'w'fw(uff
# dx),'x'fdwwf,d
# ''fd(wmUxm,mw
# ddffdfuk).
# Ixmd,fdfddudfm
# dd:.d()dud.
# (Fddwwumddd
# ufd.)Tmd:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# muuwmmu
# u
# Pmmmu
#
#
# Ofum.ROSEufu.
#
# fxm(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# mfmwf
# .Ifu''wmfx
# m.Ommu'w'fw(uff
# x),'x'fwwf,
# ''f(wmUxm,mw
# fffuk).
# Ixm,ffufm
# :.()u.
# (Fwwum
# uf.)Tm:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# uuwu
# u
# Pu
#
#
# Ofu.ROSEufu.
#
# fx(
# ff'uwk)ff
# fff
# w.(Iff,w
# uI/O,ufF.)
#
# fwf
# .Ifu''wfx
# .Ou'w'fw(uff
# x),'x'fwwf,
# ''f(wUx,w
# fffuk).
# Ix,ffuf
# :.()u.
# (Fwwu
# uf.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
# w
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'wk)ff
# fff
# w.(Iff,w
# I/O,fF.)
#
# fwf
# .If''wfx
# .O'w'fw(ff
# x),'x'fwwf,
# ''f(wUx,w
# fffk).
# Ix,fff
# :.().
# (Fww
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
# P
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# Of.ROSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/O,fF.)
#
# ff
# .If''fx
# .O''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# f.RSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/,fF.)
#
# ff
# .If''fx
# .''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# f.RSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/,fF.)
#
# ff
# .If''fx
# .''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# f.RSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/,fF.)
#
# ff
# .If''fx
# .''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# f.RSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/,fF.)
#
# ff
# .If''fx
# .''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# f.RSEf.
#
# fx(
# ff'k)ff
# fff
# .(Iff,
# I/,fF.)
#
# ff
# .If''fx
# .''f(ff
# x),'x'ff,
# ''f(Ux,
# fffk).
# Ix,fff
# :.().
# (F
# f.)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .RSE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .SE.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# .E.
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# x(
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''x
# .''(
# x),'x',
# ''(Ux,
# k).
# Ix,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# .I''
# .''(
# ),'',
# ''(U,
# k).
# I,
# :.().
# (F
# .)T:
#
#
#
#
#
#
# ..
#
# (
# 'k)
#
# .(I,
# I/,F.)
#
#
# ...
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .)T:
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):
#
#
#
#
#
#
# ..
#
# (
# ')
#
# .(,
# /,.)
#
#
# .''
# .''(
# ),'',
# ''(,
# ).
# ,
# :.().
# (
# .):

# %%
# to remove punctuations from the data.txt
with open('data.txt', 'r+') as file:
    data = file.read()
    for char in data:
        if not char.isalnum() and not ord(char) == 32:
            data = data.replace(char, '')
            # print(data)
            # print()
print(data)
# Out:
# python is a high level object oriented dynamically typed interpreted structural as well as programming language languagePython is a highlevel objectoriented dynamically typed interpreted programming languageOpen file and return a stream Raise OSError upon failurefile is either a text or byte string giving the name and the pathif the file isnt in the current working directory of the file tobe opened or an integer file descriptor of the file to bewrapped If a file descriptor is given it is closed when thereturned IO object is closed unless closefd is set to Falsemode is an optional string that specifies the mode in which the fileis opened It defaults to r which means open for reading in textmode Other common values are w for writing truncating the file ifit already exists x for creating and writing to a new file anda for appending which on some Unix systems means that all writesappend to the end of the file regardless of the current seek positionIn text mode if encoding is not specified the encoding used is platformdependent localegetencoding is called to get the current locale encodingFor reading and writing raw bytes use binary mode and leave encodingunspecified The available modes are
