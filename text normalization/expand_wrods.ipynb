# %%
print()

# %%
import contractions

# %%
# !pip install contractions

# %% [markdown]
# ## 5. I'm not okay -> I am not okay  Expanding the words

# %% [markdown]
# ## 6. ASAP -> As Soon As Possible -> Expanding the abbreviations

# %%
text1 = "I'm so excited to learn Python!"
text2 = " btw ASAP I'll try to complete the task."
expanded_text1 = contractions.fix(text1)
expanded_text2 = contractions.fix(text2)
print(expanded_text1)
print(expanded_text2)
# Out:
# I am so excited to learn Python!
#  by the way AS SOON AS POSSIBLE I will try to complete the task.

# %%
# okaay -> okay, correct the spellings
text1 = 'Okaay'
corrected_text1 = text1.replace('Okaay', 'okay')
print(corrected_text1)
# Out:
# okay

# %% [markdown]
# - We can use replace, but in real time, the data will be very large
