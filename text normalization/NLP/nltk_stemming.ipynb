# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()

# %%
# list of 20 words for stemming
words = ["playing",
"played",
"plays",
"player",
"running",
"runner",
"runs",
"studies",
"studying",
"studied",
"connected",
"connecting",
"connection",
"happiness",
"happily",
"fishing",
"fished",
"fishes",
"organized",
"organization",
"the",
"is",
"and",
"of",
"in",
"to",
"for",
"on",
"with",
"at"]
for word in words:
    print(f'{word} ---> {stemmer.stem(word)}')
# Out:
# playing ---> play
# played ---> play
# plays ---> play
# player ---> player
# running ---> run
# runner ---> runner
# runs ---> run
# studies ---> studi
# studying ---> studi
# studied ---> studi
# connected ---> connect
# connecting ---> connect
# connection ---> connect
# happiness ---> happi
# happily ---> happili
# fishing ---> fish
# fished ---> fish
# fishes ---> fish
# organized ---> organ
# organization ---> organ
# the ---> the
# is ---> is
# and ---> and
# of ---> of
# in ---> in
# to ---> to
# for ---> for
# on ---> on
# with ---> with
# at ---> at

# %% [markdown]
# - it is not converting all the words to their root forms
# - stemming is converting the word into lowercase
# - applies stemming -> HOW? -> removes the stemming based on rule

# %% [markdown]
# SOLUTION:
# - use lemmatization

# %%
# class SnowballStemmer(
#     language: Any,
#     ignore_stopwords: bool = False
# )

# %% [markdown]
# |PorterStemmer|SnowballStemmer|
# |---|---|
# |convert to lowercase| keeps actual character as it is|
# |only supports english|supports multiple language|
# |do not ignore stopwords|ignore stopwords|
#
# SnowballStemmer uses ignore_stopwords = True, but it doesn't remove stopwords

# %%
snowball_words = ["playing",
"played",
"plays",
"player",
"running",
"runner",
"runs",
"studies",
"studying",
"studied",
"connected",
"connecting",
"connection",
"happiness",
"happily",
"fishing",
"fished",
"fishes",
"organization",
"organizational",
"the",
"is",
"and",
"of",
"in",
"to",
"for",
"on",
"with",
"at"]

# %%
from nltk.stem import SnowballStemmer
snowball_stemmer = SnowballStemmer('english',ignore_stopwords=True)

# %%
for word in words:
    print(f"{word} ---> {snowball_stemmer.stem(word)}")
# Out:
# playing ---> play
# played ---> play
# plays ---> play
# player ---> player
# running ---> run
# runner ---> runner
# runs ---> run
# studies ---> studi
# studying ---> studi
# studied ---> studi
# connected ---> connect
# connecting ---> connect
# connection ---> connect
# happiness ---> happi
# happily ---> happili
# fishing ---> fish
# fished ---> fish
# fishes ---> fish
# organized ---> organ
# organization ---> organ
# the ---> the
# is ---> is
# and ---> and
# of ---> of
# in ---> in
# to ---> to
# for ---> for
# on ---> on
# with ---> with
# at ---> at

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# stop_words = stopwords.words
# stop_words
snowball_stemmer = SnowballStemmer('english', ignore_stopwords=True)
snowball_stemmer.stopwords = stop_words
snowball_stemmer.stopwords
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
for word in snowball_words:
    print(f"{word} ---> {snowball_stemmer.stem(word)}")
# Out:
# playing ---> play
# played ---> play
# plays ---> play
# player ---> player
# running ---> run
# runner ---> runner
# runs ---> run
# studies ---> studi
# studying ---> studi
# studied ---> studi
# connected ---> connect
# connecting ---> connect
# connection ---> connect
# happiness ---> happi
# happily ---> happili
# fishing ---> fish
# fished ---> fish
# fishes ---> fish
# organization ---> organ
# organizational ---> organiz
# the ---> the
# is ---> is
# and ---> and
# of ---> of
# in ---> in
# to ---> to
# for ---> for
# on ---> on
# with ---> with
# at ---> at

# %%
# which language stemmer it uses
snowball_stemmer.stemmer
