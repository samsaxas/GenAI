# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
# use word tokenize, read text file, convert into tokens, remove all stop words

# %%
with open('D:\\qsp GenAI\\text normalization\\data.txt') as file:
    data = file.read().lower()

# %%
data
# Out:
# "python is a high level object oriented dynamically typed interpreted structural as well as programming language\n language\npython is a highlevel objectoriented dynamically typed interpreted programming language\n\n\nopen file and return a stream. raise oserror upon failure.\n\nfile is either a text or byte string giving the name (and the path\nif the file isn't in the current working directory) of the file to\nbe opened or an integer file descriptor of the file to be\nwrapped. (if a file descriptor is given, it is closed when the\nreturned i/o object is closed, unless closefd is set to false.)\n\nmode is an optional string that specifies the mode in which the file\nis opened. it defaults to 'r' which means open for reading in text\nmode. other common values are 'w' for writing (truncating the file if\nit already exists), 'x' for creating and writing to a new file, and\n'a' for appending (which on some unix systems, means that all writes\nappend to the end of the file regardless of the current seek position).\nin text mode, if encoding is not specified the encoding used is platform\ndependent: locale.getencoding() is called to get the current locale encoding.\n(for reading and writing raw bytes use binary mode and leave encoding\nunspecified.) the available modes are:"

# %%
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
tokens = word_tokenize(data)

# %%
updated_tokens_word = []
for word in tokens:
    if word not in stop_words:
        updated_tokens_word.append(word)
print(updated_tokens_word)
# Out:
# ['python', 'high', 'level', 'object', 'oriented', 'dynamically', 'typed', 'interpreted', 'structural', 'well', 'programming', 'language', 'language', 'python', 'highlevel', 'objectoriented', 'dynamically', 'typed', 'interpreted', 'programming', 'language', 'open', 'file', 'return', 'stream', '.', 'raise', 'oserror', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'i/o', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'false', '.', ')', 'mode', 'optional', 'string', 'specifies', 'mode', 'file', 'opened', '.', 'defaults', "'", 'r', "'", 'means', 'open', 'reading', 'text', 'mode', '.', 'common', 'values', "'", 'w', "'", 'writing', '(', 'truncating', 'file', 'already', 'exists', ')', ',', "'", 'x', "'", 'creating', 'writing', 'new', 'file', ',', "'", "'", 'appending', '(', 'unix', 'systems', ',', 'means', 'writes', 'append', 'end', 'file', 'regardless', 'current', 'seek', 'position', ')', '.', 'text', 'mode', ',', 'encoding', 'specified', 'encoding', 'used', 'platform', 'dependent', ':', 'locale.getencoding', '(', ')', 'called', 'get', 'current', 'locale', 'encoding', '.', '(', 'reading', 'writing', 'raw', 'bytes', 'use', 'binary', 'mode', 'leave', 'encoding', 'unspecified', '.', ')', 'available', 'modes', ':']

# %%
# for word in stop_words:
#     if word in data:
#         data = data.replace(word, ' ')
# print(data)

# %%
# stop_words

# %%
with open('D:\\qsp GenAI\\text normalization\\data.txt') as file:
    data = file.read().lower()

# %%
data
# Out:
# "python is a high level object oriented dynamically typed interpreted structural as well as programming language\n language\npython is a highlevel objectoriented dynamically typed interpreted programming language\n\n\nopen file and return a stream. raise oserror upon failure.\n\nfile is either a text or byte string giving the name (and the path\nif the file isn't in the current working directory) of the file to\nbe opened or an integer file descriptor of the file to be\nwrapped. (if a file descriptor is given, it is closed when the\nreturned i/o object is closed, unless closefd is set to false.)\n\nmode is an optional string that specifies the mode in which the file\nis opened. it defaults to 'r' which means open for reading in text\nmode. other common values are 'w' for writing (truncating the file if\nit already exists), 'x' for creating and writing to a new file, and\n'a' for appending (which on some unix systems, means that all writes\nappend to the end of the file regardless of the current seek position).\nin text mode, if encoding is not specified the encoding used is platform\ndependent: locale.getencoding() is called to get the current locale encoding.\n(for reading and writing raw bytes use binary mode and leave encoding\nunspecified.) the available modes are:"

# %%
sent_tokens = sent_tokenize(data)
sent_tokens
# Out:
# ['python is a high level object oriented dynamically typed interpreted structural as well as programming language\n language\npython is a highlevel objectoriented dynamically typed interpreted programming language\n\n\nopen file and return a stream.',
#  'raise oserror upon failure.',
#  "file is either a text or byte string giving the name (and the path\nif the file isn't in the current working directory) of the file to\nbe opened or an integer file descriptor of the file to be\nwrapped.",
#  '(if a file descriptor is given, it is closed when the\nreturned i/o object is closed, unless closefd is set to false.)',
#  'mode is an optional string that specifies the mode in which the file\nis opened.',
#  "it defaults to 'r' which means open for reading in text\nmode.",
#  "other common values are 'w' for writing (truncating the file if\nit already exists), 'x' for creating and writing to a new file, and\n'a' for appending (which on some unix systems, means that all writes\nappend to the end of the file regardless of the current seek position).",
#  'in text mode, if encoding is not specified the encoding used is platform\ndependent: locale.getencoding() is called to get the current locale encoding.',
#  '(for reading and writing raw bytes use binary mode and leave encoding\nunspecified.)',
#  'the available modes are:']

# %%
updated_tokens_sent = []
for sentence in tokens:
    if sentence not in stop_words:
        updated_tokens_sent.append(sentence)
print(updated_tokens_sent, end = ' ')
# Out:
# ['python', 'high', 'level', 'object', 'oriented', 'dynamically', 'typed', 'interpreted', 'structural', 'well', 'programming', 'language', 'language', 'python', 'highlevel', 'objectoriented', 'dynamically', 'typed', 'interpreted', 'programming', 'language', 'open', 'file', 'return', 'stream', '.', 'raise', 'oserror', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'i/o', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'false', '.', ')', 'mode', 'optional', 'string', 'specifies', 'mode', 'file', 'opened', '.', 'defaults', "'", 'r', "'", 'means', 'open', 'reading', 'text', 'mode', '.', 'common', 'values', "'", 'w', "'", 'writing', '(', 'truncating', 'file', 'already', 'exists', ')', ',', "'", 'x', "'", 'creating', 'writing', 'new', 'file', ',', "'", "'", 'appending', '(', 'unix', 'systems', ',', 'means', 'writes', 'append', 'end', 'file', 'regardless', 'current', 'seek', 'position', ')', '.', 'text', 'mode', ',', 'encoding', 'specified', 'encoding', 'used', 'platform', 'dependent', ':', 'locale.getencoding', '(', ')', 'called', 'get', 'current', 'locale', 'encoding', '.', '(', 'reading', 'writing', 'raw', 'bytes', 'use', 'binary', 'mode', 'leave', 'encoding', 'unspecified', '.', ')', 'available', 'modes', ':']

# %%
print(len(updated_tokens_word))
print(updated_tokens_word)
# Out:
# 163
# ['python', 'high', 'level', 'object', 'oriented', 'dynamically', 'typed', 'interpreted', 'structural', 'well', 'programming', 'language', 'language', 'python', 'highlevel', 'objectoriented', 'dynamically', 'typed', 'interpreted', 'programming', 'language', 'open', 'file', 'return', 'stream', '.', 'raise', 'oserror', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'i/o', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'false', '.', ')', 'mode', 'optional', 'string', 'specifies', 'mode', 'file', 'opened', '.', 'defaults', "'", 'r', "'", 'means', 'open', 'reading', 'text', 'mode', '.', 'common', 'values', "'", 'w', "'", 'writing', '(', 'truncating', 'file', 'already', 'exists', ')', ',', "'", 'x', "'", 'creating', 'writing', 'new', 'file', ',', "'", "'", 'appending', '(', 'unix', 'systems', ',', 'means', 'writes', 'append', 'end', 'file', 'regardless', 'current', 'seek', 'position', ')', '.', 'text', 'mode', ',', 'encoding', 'specified', 'encoding', 'used', 'platform', 'dependent', ':', 'locale.getencoding', '(', ')', 'called', 'get', 'current', 'locale', 'encoding', '.', '(', 'reading', 'writing', 'raw', 'bytes', 'use', 'binary', 'mode', 'leave', 'encoding', 'unspecified', '.', ')', 'available', 'modes', ':']

# %%
print(len(updated_tokens_sent))
print(updated_tokens_sent)
# Out:
# 163
# ['python', 'high', 'level', 'object', 'oriented', 'dynamically', 'typed', 'interpreted', 'structural', 'well', 'programming', 'language', 'language', 'python', 'highlevel', 'objectoriented', 'dynamically', 'typed', 'interpreted', 'programming', 'language', 'open', 'file', 'return', 'stream', '.', 'raise', 'oserror', 'upon', 'failure', '.', 'file', 'either', 'text', 'byte', 'string', 'giving', 'name', '(', 'path', 'file', "n't", 'current', 'working', 'directory', ')', 'file', 'opened', 'integer', 'file', 'descriptor', 'file', 'wrapped', '.', '(', 'file', 'descriptor', 'given', ',', 'closed', 'returned', 'i/o', 'object', 'closed', ',', 'unless', 'closefd', 'set', 'false', '.', ')', 'mode', 'optional', 'string', 'specifies', 'mode', 'file', 'opened', '.', 'defaults', "'", 'r', "'", 'means', 'open', 'reading', 'text', 'mode', '.', 'common', 'values', "'", 'w', "'", 'writing', '(', 'truncating', 'file', 'already', 'exists', ')', ',', "'", 'x', "'", 'creating', 'writing', 'new', 'file', ',', "'", "'", 'appending', '(', 'unix', 'systems', ',', 'means', 'writes', 'append', 'end', 'file', 'regardless', 'current', 'seek', 'position', ')', '.', 'text', 'mode', ',', 'encoding', 'specified', 'encoding', 'used', 'platform', 'dependent', ':', 'locale.getencoding', '(', ')', 'called', 'get', 'current', 'locale', 'encoding', '.', '(', 'reading', 'writing', 'raw', 'bytes', 'use', 'binary', 'mode', 'leave', 'encoding', 'unspecified', '.', ')', 'available', 'modes', ':']

# %%
nlp_sentence = ["NLP stands for Natural Language Processing.",
"NLP enables computers to understand human language.",
"NLP combines linguistics with artificial intelligence.",
"NLP is used in chatbots and virtual assistants.",
"NLP helps analyze text and speech data.",
"NLP powers machine translation systems.",
"NLP is used for sentiment analysis.",
"NLP can summarize large amounts of text.",
"NLP improves communication between humans and machines.",
"NLP has applications in healthcare, education, and business."]
# create 10 sentences for nlp

# %%
# assignment
# sentence level + stop word removal
